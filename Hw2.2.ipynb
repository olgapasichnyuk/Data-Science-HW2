# %%
import pandas as pd
import numpy as np

# %%
#Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv
data = pd.read_csv('https://drive.google.com/u/0/uc?id=1JMYqXipZpz9Y5-vyxvLEO2Y1sRBxqu-U&export=download')
data
# Out:
#          N                 Должность Язык.программирования Специализация  \
# 0        1        Junior QA engineer                   NaN     Manual QA
# 1        2        Junior QA engineer                   NaN     Manual QA
# 2        3         Software Engineer               C#/.NET           NaN
# 3        4         Software Engineer            JavaScript           NaN
# 4        5  Senior Software Engineer            JavaScript           NaN
# ...    ...                       ...                   ...           ...
# 8699  8700               QA engineer                   NaN     Manual QA
# 8700  8701                 Marketing                   NaN           NaN
# 8701  8702  Junior Software Engineer            Ruby/Rails           NaN
# 8702  8703                 Team lead                   NaN           NaN
# 8703  8704  Senior Software Engineer                  Java           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# ...

# %%
import seaborn as sns
sns.scatterplot(x="Зарплата.в.месяц", y="Город", data=data)
# Out:
# <Axes: xlabel='Зарплата.в.месяц', ylabel='Город'>

# %%
s = sns.stripplot(x="Уровень.английского", y="Зарплата.в.месяц", data=data)
s.set_xticklabels(s.get_xticklabels(),rotation = 45)
# Out:
# C:\Users\olgapasichnyuk\AppData\Local\Temp\ipykernel_17620\3709260121.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   s.set_xticklabels(s.get_xticklabels(),rotation = 45)
# [Text(0, 0, 'ниже среднего'),
#  Text(1, 0, 'выше среднего'),
#  Text(2, 0, 'средний'),
#  Text(3, 0, 'продвинутый'),
#  Text(4, 0, 'элементарный')]

# %%
#Прочитайте отриману таблицю, використовуючи метод head
data.head()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# ...

# %%
#Визначте розмір таблиці за допомогою методу shape
data.shape
# Out:
# (8704, 25)

# %%
#Визначте типи всіх стовпців за допомогою dataframe.dtypes
data.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# ...

# %%
#Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)
spaces = data.isnull()
res = pd.DataFrame()
res['amount_of_spaces'] = np.sum(spaces, axis=0)
res['part_of_spaces_%'] = (np.sum(spaces, axis=0) / spaces.shape[0]) *100
res
# Out:
#                                   amount_of_spaces  part_of_spaces_%
# N                                                0          0.000000
# Должность                                        0          0.000000
# Язык.программирования                         3850         44.232537
# Специализация                                 7219         82.938879
# Общий.опыт.работы                                0          0.000000
# Опыт.работы.на.текущем.месте                     0          0.000000
# Зарплата.в.месяц                                 0          0.000000
# Изменение.зарплаты.за.12.месяцев                 0          0.000000
# Город                                            0          0.000000
# Размер.компании                                  0          0.000000
# Тип.компании                                     0          0.000000
# Пол                                              0          0.000000
# Возраст                                          0          0.000000
# ...

# %%
#Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"
data = data.drop([i for i in res.index if res.loc[i][0] > 0 and i != 'Язык.программирования'], axis=1, inplace=False)
data.head()
# Out:
#    N                 Должность Язык.программирования Общий.опыт.работы  \
# 0  1        Junior QA engineer                   NaN               0.5
# 1  2        Junior QA engineer                   NaN  меньше 3 месяцев
# 2  3         Software Engineer               C#/.NET                 4
# 3  4         Software Engineer            JavaScript                 5
# 4  5  Senior Software Engineer            JavaScript    10 и более лет
#
#   Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0                          0.5               400
# 1             меньше 3 месяцев               430
# 2                            1              2500
# 3                            4              2000
# 4                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  \
# 0                                 0  Харьков       до 10 человек
# 1                               130  Харьков  свыше 1000 человек
# ...

# %%
#Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

spaces = data.isnull()
res = pd.DataFrame()
res['amount_of_spaces'] = np.sum(spaces, axis=0)
res['part_of_spaces_%'] = (np.sum(spaces, axis=0) / spaces.shape[0]) *100
res
# Out:
#                                   amount_of_spaces  part_of_spaces_%
# N                                                0          0.000000
# Должность                                        0          0.000000
# Язык.программирования                         3850         44.232537
# Общий.опыт.работы                                0          0.000000
# Опыт.работы.на.текущем.месте                     0          0.000000
# Зарплата.в.месяц                                 0          0.000000
# Изменение.зарплаты.за.12.месяцев                 0          0.000000
# Город                                            0          0.000000
# Размер.компании                                  0          0.000000
# Тип.компании                                     0          0.000000
# Пол                                              0          0.000000
# Возраст                                          0          0.000000
# Образование                                      0          0.000000
# ...

# %%
#Видаліть усі рядки у вихідній таблиці за допомогою методу dropna
data.dropna
# Out:
# <bound method DataFrame.dropna of          N                 Должность Язык.программирования Общий.опыт.работы  \
# 2        3         Software Engineer               C#/.NET                 4
# 3        4         Software Engineer            JavaScript                 5
# 4        5  Senior Software Engineer            JavaScript    10 и более лет
# 6        7  Junior Software Engineer               C#/.NET                 1
# 7        8  Senior Software Engineer                   C++                 6
# ...    ...                       ...                   ...               ...
# 8692  8693         Software Engineer                  Java                 5
# 8694  8695  Junior Software Engineer               C#/.NET                 1
# 8695  8696         Software Engineer                Python                 1
# 8701  8702  Junior Software Engineer            Ruby/Rails                 1
# 8703  8704  Senior Software Engineer                  Java                 7
#
# ...

# %%
#Визначте новий розмір таблиці за допомогою методу shape

data.shape
# Out:
# (4854, 20)

# %%
#Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python
python_data = data[data['Язык.программирования'] == 'Python']
python_data
# Out:
#          N                 Должность Язык.программирования Общий.опыт.работы  \
# 12      13         Software Engineer                Python                 1
# 68      69         Software Engineer                Python               1.5
# 87      88  Junior Software Engineer                Python               0.5
# 114    115  Junior Software Engineer                Python               1.5
# 143    144  Junior Software Engineer                Python                 1
# ...    ...                       ...                   ...               ...
# 8546  8547         Software Engineer                Python                 5
# 8625  8626         Software Engineer                Python                 4
# 8635  8636  Senior Software Engineer                Python    10 и более лет
# 8673  8674  Junior Software Engineer                Python               0.5
# 8695  8696         Software Engineer                Python                 1
#
# ...

# %%
#Визначте розмір таблиці python_data за допомогою методу shape

python_data.shape
# Out:
# (207, 20)

# %%
#Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

python_data.groupby('Должность')

# %%
#Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада"
#виконайте агрегацію даних за допомогою методу agg і знайдіть
#мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"

new_python_data = python_data.groupby('Должность')
res = new_python_data.agg({'Зарплата.в.месяц':['min', 'max']})
res
# Out:
#                          Зарплата.в.месяц
#                                       min   max
# Должность
# Junior Software Engineer              100  1250
# Senior Software Engineer             1300  9200
# Software Engineer                     500  5400
# System Architect                     3000  5000
# Technical Lead                       1425  6200

# %%
#Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць.
#Використовуйте її для методу apply та створіть новий стовпчик "avg"


def fill_avg_salary(salary):
    return salary.mean()

res['avg'] = res.apply(fill_avg_salary, axis=1)
res
# Out:
#                          Зарплата.в.месяц           avg
#                                       min   max
# Должность
# Junior Software Engineer              100  1250   675.0
# Senior Software Engineer             1300  9200  5250.0
# Software Engineer                     500  5400  2950.0
# System Architect                     3000  5000  4000.0
# Technical Lead                       1425  6200  3812.5

# %%
#Створіть описову статистику за допомогою методу describe для нового стовпчика.

res['avg'].describe
# Out:
# <bound method NDFrame.describe of Должность
# Junior Software Engineer     675.0
# Senior Software Engineer    5250.0
# Software Engineer           2950.0
# System Architect            4000.0
# Technical Lead              3812.5
# Name: avg, dtype: float64>

# %%
#Збережіть отриману таблицю в CSV файл

res.to_csv("data.csv", index=False)

# %%
import seaborn as sns
s = sns.lineplot(data=res)

s.set_xticklabels(s.get_xticklabels(),rotation = 45)
# Out:
# C:\Users\olgapasichnyuk\AppData\Local\Temp\ipykernel_17620\735913849.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   s.set_xticklabels(s.get_xticklabels(),rotation = 45)
# [Text(0, 0, 'Junior Software Engineer'),
#  Text(1, 0, 'Senior Software Engineer'),
#  Text(2, 0, 'Software Engineer'),
#  Text(3, 0, 'System Architect'),
#  Text(4, 0, 'Technical Lead')]
